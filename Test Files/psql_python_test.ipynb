# %% [markdown]
# ### Required Libraries

# %%
# !pip install SQLAlchemy
# !pip install psycopg2
# !pip install pandas
# Out:
# Requirement already satisfied: SQLAlchemy in /Users/rohan/anaconda3/lib/python3.11/site-packages (2.0.31)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/rohan/anaconda3/lib/python3.11/site-packages (from SQLAlchemy) (4.12.1)
# Requirement already satisfied: psycopg2 in /Users/rohan/anaconda3/lib/python3.11/site-packages (2.9.9)
# Requirement already satisfied: pandas in /Users/rohan/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rohan/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/rohan/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/rohan/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/rohan/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/rohan/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
from sqlalchemy import create_engine
from sqlalchemy import inspect
engine = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/mimic')

# %%
# select tables from the mimiciii schema
inspector = inspect(engine)
schemas = inspector.get_schema_names()
print(schemas)

for table_name in inspector.get_table_names(schema='mimiciii'):
    print("Table: ", table_name)
    for column in inspector.get_columns(table_name, schema='mimiciii'):
        print("Column: %s" % column['name'])
# Out:
# ['information_schema', 'mimiciii', 'public']
# Table:  admissions
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: admittime
# Column: dischtime
# Column: deathtime
# Column: admission_type
# Column: admission_location
# Column: discharge_location
# Column: insurance
# Column: language
# Column: religion
# Column: marital_status
# Column: ethnicity
# Column: edregtime
# Column: edouttime
# Column: diagnosis
# Column: hospital_expire_flag
# Column: has_chartevents_data
# Table:  callout
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: submit_wardid
# Column: submit_careunit
# Column: curr_wardid
# Column: curr_careunit
# Column: callout_wardid
# Column: callout_service
# Column: request_tele
# Column: request_resp
# Column: request_cdiff
# Column: request_mrsa
# Column: request_vre
# Column: callout_status
# Column: callout_outcome
# Column: discharge_wardid
# Column: acknowledge_status
# Column: createtime
# Column: updatetime
# Column: acknowledgetime
# Column: outcometime
# Column: firstreservationtime
# Column: currentreservationtime
# Table:  caregivers
# Column: row_id
# Column: cgid
# Column: label
# Column: description
# Table:  chartevents_1
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_2
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_3
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_4
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_5
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_6
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_7
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_8
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_9
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_10
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_11
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_12
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_13
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_14
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_15
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_16
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents_17
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  chartevents
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valuenum
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  cptevents
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: costcenter
# Column: chartdate
# Column: cpt_cd
# Column: cpt_number
# Column: cpt_suffix
# Column: ticket_id_seq
# Column: sectionheader
# Column: subsectionheader
# Column: description
# Table:  datetimeevents
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: itemid
# Column: charttime
# Column: storetime
# Column: cgid
# Column: value
# Column: valueuom
# Column: warning
# Column: error
# Column: resultstatus
# Column: stopped
# Table:  diagnoses_icd
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: seq_num
# Column: icd9_code
# Table:  drgcodes
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: drg_type
# Column: drg_code
# Column: description
# Column: drg_severity
# Column: drg_mortality
# Table:  d_cpt
# Column: row_id
# Column: category
# Column: sectionrange
# Column: sectionheader
# Column: subsectionrange
# Column: subsectionheader
# Column: codesuffix
# Column: mincodeinsubsection
# Column: maxcodeinsubsection
# Table:  d_icd_diagnoses
# Column: row_id
# Column: icd9_code
# Column: short_title
# Column: long_title
# Table:  d_icd_procedures
# Column: row_id
# Column: icd9_code
# Column: short_title
# Column: long_title
# Table:  d_items
# Column: row_id
# Column: itemid
# Column: label
# Column: abbreviation
# Column: dbsource
# Column: linksto
# Column: category
# Column: unitname
# Column: param_type
# Column: conceptid
# Table:  d_labitems
# Column: row_id
# Column: itemid
# Column: label
# Column: fluid
# Column: category
# Column: loinc_code
# Table:  icustays
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: dbsource
# Column: first_careunit
# Column: last_careunit
# Column: first_wardid
# Column: last_wardid
# Column: intime
# Column: outtime
# Column: los
# Table:  inputevents_cv
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: charttime
# Column: itemid
# Column: amount
# Column: amountuom
# Column: rate
# Column: rateuom
# Column: storetime
# Column: cgid
# Column: orderid
# Column: linkorderid
# Column: stopped
# Column: newbottle
# Column: originalamount
# Column: originalamountuom
# Column: originalroute
# Column: originalrate
# Column: originalrateuom
# Column: originalsite
# Table:  inputevents_mv
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: starttime
# Column: endtime
# Column: itemid
# Column: amount
# Column: amountuom
# Column: rate
# Column: rateuom
# Column: storetime
# Column: cgid
# Column: orderid
# Column: linkorderid
# Column: ordercategoryname
# Column: secondaryordercategoryname
# Column: ordercomponenttypedescription
# Column: ordercategorydescription
# Column: patientweight
# Column: totalamount
# Column: totalamountuom
# Column: isopenbag
# Column: continueinnextdept
# Column: cancelreason
# Column: statusdescription
# Column: comments_editedby
# Column: comments_canceledby
# Column: comments_date
# Column: originalamount
# Column: originalrate
# Table:  labevents
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: itemid
# Column: charttime
# Column: value
# Column: valuenum
# Column: valueuom
# Column: flag
# Table:  microbiologyevents
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: chartdate
# Column: charttime
# Column: spec_itemid
# Column: spec_type_desc
# Column: org_itemid
# Column: org_name
# Column: isolate_num
# Column: ab_itemid
# Column: ab_name
# Column: dilution_text
# Column: dilution_comparison
# Column: dilution_value
# Column: interpretation
# Table:  noteevents
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: chartdate
# Column: charttime
# Column: storetime
# Column: category
# Column: description
# Column: cgid
# Column: iserror
# Column: text
# Table:  outputevents
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: charttime
# Column: itemid
# Column: value
# Column: valueuom
# Column: storetime
# Column: cgid
# Column: stopped
# Column: newbottle
# Column: iserror
# Table:  patients
# Column: row_id
# Column: subject_id
# Column: gender
# Column: dob
# Column: dod
# Column: dod_hosp
# Column: dod_ssn
# Column: expire_flag
# Table:  prescriptions
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: startdate
# Column: enddate
# Column: drug_type
# Column: drug
# Column: drug_name_poe
# Column: drug_name_generic
# Column: formulary_drug_cd
# Column: gsn
# Column: ndc
# Column: prod_strength
# Column: dose_val_rx
# Column: dose_unit_rx
# Column: form_val_disp
# Column: form_unit_disp
# Column: route
# Table:  procedureevents_mv
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: starttime
# Column: endtime
# Column: itemid
# Column: value
# Column: valueuom
# Column: location
# Column: locationcategory
# Column: storetime
# Column: cgid
# Column: orderid
# Column: linkorderid
# Column: ordercategoryname
# Column: secondaryordercategoryname
# Column: ordercategorydescription
# Column: isopenbag
# Column: continueinnextdept
# Column: cancelreason
# Column: statusdescription
# Column: comments_editedby
# Column: comments_canceledby
# Column: comments_date
# Table:  procedures_icd
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: seq_num
# Column: icd9_code
# Table:  services
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: transfertime
# Column: prev_service
# Column: curr_service
# Table:  transfers
# Column: row_id
# Column: subject_id
# Column: hadm_id
# Column: icustay_id
# Column: dbsource
# Column: eventtype
# Column: prev_careunit
# Column: curr_careunit
# Column: prev_wardid
# Column: curr_wardid
# Column: intime
# Column: outtime
# Column: los

# %%
import pandas as pd

# Test pandas read_sql_query
df = pd.read_sql_query('SELECT * FROM mimiciii.admissions', engine)

df.head()
# Out:
#    row_id  subject_id  hadm_id           admittime           dischtime  \
# 0      21          22   165315 2196-04-09 12:26:00 2196-04-10 15:54:00
# 1      22          23   152223 2153-09-03 07:15:00 2153-09-08 19:10:00
# 2      23          23   124321 2157-10-18 19:34:00 2157-10-25 14:00:00
# 3      24          24   161859 2139-06-06 16:14:00 2139-06-09 12:48:00
# 4      25          25   129635 2160-11-02 02:06:00 2160-11-05 14:55:00
#
#   deathtime admission_type         admission_location  \
# 0       NaT      EMERGENCY       EMERGENCY ROOM ADMIT
# 1       NaT       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 2       NaT      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3       NaT      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 4       NaT      EMERGENCY       EMERGENCY ROOM ADMIT
#
#           discharge_location insurance language           religion  \
# 0  DISC-TRAN CANCER/CHLDRN H   Private     None       UNOBTAINABLE
# 1           HOME HEALTH CARE  Medicare     None           CATHOLIC
# 2           HOME HEALTH CARE  Medicare     ENGL           CATHOLIC
# 3                       HOME   Private     None  PROTESTANT QUAKER
# 4                       HOME   Private     None       UNOBTAINABLE
#
#   marital_status ethnicity           edregtime           edouttime  \
# 0        MARRIED     WHITE 2196-04-09 10:06:00 2196-04-09 13:24:00
# 1        MARRIED     WHITE                 NaT                 NaT
# 2        MARRIED     WHITE                 NaT                 NaT
# 3         SINGLE     WHITE                 NaT                 NaT
# 4        MARRIED     WHITE 2160-11-02 01:01:00 2160-11-02 04:27:00
#
#                                            diagnosis  hospital_expire_flag  \
# 0                            BENZODIAZEPINE OVERDOSE                     0
# 1  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 2                                         BRAIN MASS                     0
# 3                     INTERIOR MYOCARDIAL INFARCTION                     0
# 4                            ACUTE CORONARY SYNDROME                     0
#
#    has_chartevents_data
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
